# %% [markdown]
# # Использование Kubric для генерации изображений/видео
#
# Базируется на PyBullet
# https://pybullet.org/wordpress/index.php/2022/03/21/kubric-a-scalable-dataset-generator/

# %%
# !git clone https://github.com/google-research/kubric.git
# Out:
# Cloning into 'kubric'...
# remote: Enumerating objects: 4607, done.
# remote: Counting objects: 100% (600/600), done.
# remote: Compressing objects: 100% (320/320), done.
# remote: Total 4607 (delta 373), reused 467 (delta 278), pack-reused 4007
# Receiving objects: 100% (4607/4607), 75.10 MiB | 19.04 MiB/s, done.
# Resolving deltas: 100% (3003/3003), done.

# %% [markdown]
# Докер в Colab
#
# https://gist.github.com/mwufi/6718b30761cd109f9aff04c5144eb885?permalink_comment_id=4673355#gistcomment-4673355
#
# Страница проекта
#
# https://github.com/indigo-dc/udocker
#
# Официальная инструкция по установке
#
# https://indigo-dc.github.io/udocker/installation_manual.html

# %%
# !pip install udocker
# !udocker --allow-root install
# !udocker --allow-root pull kubricdockerhub/kubruntu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 1.6 MB/s eta 0:00:00
# ...
# Info: creating repo: /root/.udocker
# Info: udocker command line interface 1.3.13
# Info: searching for udockertools >= 1.2.11
# Info: installing udockertools 1.2.11
# Info: installation of udockertools successful
# Info: downloading layer sha256:9dd8f5f23f74846a9309f8799323318b336ca8bbf77f5efd4b5aa2532d41f4a5
# Info: downloading layer sha256:50b29bbbbb236038c24bfc0b3ec930fd54912a03939917970ccb139abeed2c1a
# Info: downloading layer sha256:b8b4490bac3ab0a3552b3b0db54cbac1ef1df9f2a5aeb2e8affa488dd1cc3e4a
# Info: downloading layer sha256:9e44cccff2eee7a79c334463d9080fac5a1a0b506306943b234f485571ae3b21
# Info: downloading layer sha256:2740444466e2f9a038da515826c38f077b88960e8ee1e591816e55bdbb2c0a43
# Info: downloading layer sha256:b4c2b8630140ce2d0269136acb552962620f7c9ea19499616a9ffa61e6c90c11
# Info: downloading layer sha256:b184f08b56b679eb10df881865146d68743872ec830beaccc18c64d8b6e07145
# ...

# %% [markdown]
# Пакет "Кубрик" для генерации реалистичных изображений и видео
#
# https://github.com/google-research/kubric

# %%
# !udocker --allow-root run --rm --volume /content/kubric:/kubric \
    --user $(id -u):$(id -g) kubricdockerhub/kubruntu \
    python3 examples/helloworld.py
# Out:
#
#  ******************************************************************************
#  *                                                                            *
#  *               STARTING 80c294b6-d3a8-3da5-8e16-83f079dbed7a                *
#  *                                                                            *
#  ******************************************************************************
#  executing: python3
# could not get a list of mounted file-systems
# INFO:kubric.renderer.blender:Saving 'output/helloworld.blend'
# INFO:kubric.renderer.blender:Using scratch rendering folder: '/tmp/tmponlkof2k'
# INFO:kubric.renderer.blender:Rendered frame '/tmp/tmponlkof2k/images/frame_0001.png'
# INFO:root:Writing to 'output/helloworld.png'
# INFO:root:Writing to 'output/helloworld_segmentation.png'
# INFO:root:Writing to 'output/helloworld_depth.png'
# INFO:root:Depth scale: {'min': 3.3596720695495605, 'max': 10.476555824279785}
# ...

# %%
from IPython.display import Image
Image('kubric/output/helloworld.png')

# %%
Image('kubric/output/helloworld_depth.png')

# %%
Image('kubric/output/helloworld_segmentation.png')
